# %%
from qiskit_nature.second_q.operators import FermionicOp

def hamiltonian_original():
    Vbc = [[-.0665824175665474],
           [.0491028058707432]]
    Eb = -.0632948702054110
    U = 0.29340000
    eps_1 = -0.284183
    eps_2 = -0.2632707
    n_bath = 1
    n_impurity = 2
    
    # Initialize the Hamiltonian
    H = FermionicOp({}, num_spin_orbitals=6)

    # Add the on-site interaction terms
    H += U * FermionicOp({"+_0 -_0 +_1 -_1": 1}, num_spin_orbitals=6)
    H += U * FermionicOp({"+_2 -_2 +_3 -_3": 1}, num_spin_orbitals=6)
    H += eps_1 * (FermionicOp({"+_0 -_0": 1}, num_spin_orbitals=6) +
                   FermionicOp({"+_1 -_1": 1}, num_spin_orbitals=6))
    H += eps_2 * (FermionicOp({"+_2 -_2": 1}, num_spin_orbitals=6) +
                   FermionicOp({"+_3 -_3": 1}, num_spin_orbitals=6))

    # Add the coupling terms
    for f in range(n_impurity):
        for d in range(n_bath):
            factor = Vbc[f][d]
            term_even = f"+_{2*f} -_{2*(2+d)} +_{2*(2+d)} -_{2*f}"
            term_odd = f"+_{2*f + 1} -_{2*(2+d) + 1} +_{2*(2+d) + 1} -_{2*f + 1}"
            H += factor * FermionicOp({term_even: 1}, num_spin_orbitals=6)
            H += factor * FermionicOp({term_odd: 1}, num_spin_orbitals=6)

    # Add the last terms for Eb
    H += Eb * (FermionicOp({"+_4 -_4": 1}, num_spin_orbitals=6) +
                FermionicOp({"+_5 -_5": 1}, num_spin_orbitals=6))

    return H

# Create the Hamiltonian
hamiltonian_fermionic_op = hamiltonian_original()
print(hamiltonian_fermionic_op)
# Out:
# Fermionic Operator
# number spin orbitals=6, number terms=12
#   0.2934 * ( +_0 -_0 +_1 -_1 )
# + 0.2934 * ( +_2 -_2 +_3 -_3 )
# + -0.284183 * ( +_0 -_0 )
# + -0.284183 * ( +_1 -_1 )
# + -0.2632707 * ( +_2 -_2 )
# + -0.2632707 * ( +_3 -_3 )
# + -0.0665824175665474 * ( +_0 -_4 +_4 -_0 )
# + -0.0665824175665474 * ( +_1 -_5 +_5 -_1 )
# + 0.0491028058707432 * ( +_2 -_4 +_4 -_2 )
# + 0.0491028058707432 * ( +_3 -_5 +_5 -_3 )
# + -0.063294870205411 * ( +_4 -_4 )
# + -0.063294870205411 * ( +_5 -_5 )

# %%
Spin_Correlator = FermionicOp({}, num_spin_orbitals=6)
Spin_Correlator += FermionicOp({"+_0 +_2": 0.5}, num_spin_orbitals=6)
Spin_Correlator += FermionicOp({"+_1 +_3": 0.5}, num_spin_orbitals=6)
Spin_Correlator += FermionicOp({"+_1 +_2": -0.5}, num_spin_orbitals=6)
Spin_Correlator += FermionicOp({"+_0 +_3": -0.5}, num_spin_orbitals=6)

# %%
from qiskit_nature.second_q.operators import SparseLabelOp
from qiskit_algorithms import EigensolverResult, MinimumEigensolverResult
from qiskit_nature.second_q.problems.eigenstate_result import EigenstateResult

class HamiltonianProblem:
    def __init__(self, hamiltonian: SparseLabelOp, aux_ops: SparseLabelOp):
        self._hamiltonian = hamiltonian
        self.aux_ops = aux_ops
        self.properties = []  # Add any properties you may have here

    @property
    def hamiltonian(self) -> SparseLabelOp:
        """Returns the Hamiltonian wrapped by this problem."""
        return self._hamiltonian

    def second_q_ops(self) -> tuple[SparseLabelOp, dict[str, SparseLabelOp]]:
        """Returns the second quantized operators associated with this problem.

        Returns:
            A tuple, with the first object being the main operator and the second being a dictionary
            of auxiliary operators.
        """
        main_op = self.hamiltonian  # Already a SparseLabelOp

        aux_ops: dict[str, SparseLabelOp] = {}

        aux_ops['spin_correlator'] = self.aux_ops
        
        for prop in self.properties:
            aux_ops.update(prop.second_q_ops())

        return main_op, aux_ops
    
    def interpret(
            self,
            raw_result: EigenstateResult | EigensolverResult | MinimumEigensolverResult,
        ) -> EigenstateResult:
            """Interprets an EigenstateResult in the context of this problem.

            Args:
                raw_result: an eigenstate result object.

            Returns:
                An interpreted `EigenstateResult` in the form of a subclass of it. The actual type
                depends on the problem that implements this method.
            """
            return EigenstateResult.from_result(raw_result)
    

# Define the Hamiltonian terms and coefficients
hamiltonian_terms = hamiltonian_original()
print(hamiltonian_terms)

# Create an instance of HamiltonianProblem
problem = HamiltonianProblem(hamiltonian_terms, Spin_Correlator)

# Access the second quantized operators
main_operator, auxiliary_operators = problem.second_q_ops()

print(main_operator)
print(auxiliary_operators)
# Out:
# Fermionic Operator
# number spin orbitals=6, number terms=12
#   0.2934 * ( +_0 -_0 +_1 -_1 )
# + 0.2934 * ( +_2 -_2 +_3 -_3 )
# + -0.284183 * ( +_0 -_0 )
# + -0.284183 * ( +_1 -_1 )
# + -0.2632707 * ( +_2 -_2 )
# + -0.2632707 * ( +_3 -_3 )
# + -0.0665824175665474 * ( +_0 -_4 +_4 -_0 )
# + -0.0665824175665474 * ( +_1 -_5 +_5 -_1 )
# + 0.0491028058707432 * ( +_2 -_4 +_4 -_2 )
# + 0.0491028058707432 * ( +_3 -_5 +_5 -_3 )
# + -0.063294870205411 * ( +_4 -_4 )
# + -0.063294870205411 * ( +_5 -_5 )
# Fermionic Operator
# number spin orbitals=6, number terms=12
#   0.2934 * ( +_0 -_0 +_1 -_1 )
# + 0.2934 * ( +_2 -_2 +_3 -_3 )
# + -0.284183 * ( +_0 -_0 )
# + -0.284183 * ( +_1 -_1 )
# + -0.2632707 * ( +_2 -_2 )
# + -0.2632707 * ( +_3 -_3 )
# + -0.0665824175665474 * ( +_0 -_4 +_4 -_0 )
# + -0.0665824175665474 * ( +_1 -_5 +_5 -_1 )
# + 0.0491028058707432 * ( +_2 -_4 +_4 -_2 )
# + 0.0491028058707432 * ( +_3 -_5 +_5 -_3 )
# + -0.063294870205411 * ( +_4 -_4 )
# + -0.063294870205411 * ( +_5 -_5 )
# {'spin_correlator': FermionicOp({'+_0 +_2': 0.5, '+_1 +_3': 0.5, '+_1 +_2': -0.5, '+_0 +_3': -0.5}, num_spin_orbitals=6, )}

# %%
from qiskit_algorithms import NumPyMinimumEigensolver
from qiskit_nature.second_q.algorithms import GroundStateEigensolver

exact_solver = NumPyMinimumEigensolver()
calc = GroundStateEigensolver(JordanWignerMapper(), exact_solver)
result = calc.solve(problem)
print(result)
# Out:
# {   'aux_operators_evaluated': [{'spin_correlator': 0.0}],
#     'eigenstates': [   (   <qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x31872d2b0>,
#                            None)],
#     'eigenvalues': array([-0.67733099+0.j]),
#     'formatting_precision': 12,
#     'groundenergy': -0.6773309877719585,
#     'groundstate': (   <qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x31872d2b0>,
#                        None),
#     'raw_result': <qiskit_algorithms.minimum_eigensolvers.numpy_minimum_eigensolver.NumPyMinimumEigensolverResult object at 0x3186da540>}

# %%
from typing import Callable, Any, Dict
import numpy as np

# Initialize lists to store the data
evaluation_counts = []
params_list = []
estimated_values = []
metadata_list = []

def optimization_callback(evaluation_count: int, params: np.ndarray, estimated_value: float, metadata: Dict[str, Any]) -> None:
    """
    Callback function to access intermediate data at each optimization step.

    Args:
        evaluation_count (int): The current count of evaluations.
        params (np.ndarray): The current optimizer parameters for the ansatz.
        estimated_value (float): The estimated value at this step.
        metadata (Dict[str, Any]): A dictionary containing metadata about the optimization process.
    """
    # Save the data into arrays/lists
    evaluation_counts.append(evaluation_count)
    params_list.append(params.copy())  # Use copy to avoid references
    estimated_values.append(estimated_value)
    metadata_list.append(metadata.copy())  # Use copy if metadata is mutable

    # Optional: Print the data for confirmation
    print(f"Evaluation Count: {evaluation_count}")
    print(f"Parameters: {params}")
    print(f"Estimated Value: {estimated_value}")
    print(f"Metadata: {metadata}")

# Example usage:
callback: Callable[[int, np.ndarray, float, Dict[str, Any]], None] = optimization_callback

# After optimization, you can convert lists to numpy arrays if needed:
evaluation_counts_array = np.array(evaluation_counts)
params_array = np.array(params_list)  # Note: This will be a 2D array if params have different lengths
estimated_values_array = np.array(estimated_values)
metadata_array = np.array(metadata_list)  # This will also be a 2D array or object array

# Example: Print final stored data
print("Final Evaluation Counts:", evaluation_counts_array)
print("Final Parameters Array:", params_array)
print("Final Estimated Values:", estimated_values_array)
print("Final Metadata Array:", metadata_array)
# Out:
# Final Evaluation Counts: []
# Final Parameters Array: []
# Final Estimated Values: []
# Final Metadata Array: []

# %%
from qiskit_algorithms.optimizers import SPSA
from qiskit_algorithms import VQE
from qiskit_aer.primitives import Estimator as AerEstimator
from qiskit_nature.second_q.algorithms import GroundStateEigensolver
from qiskit_nature.second_q.circuit.library import UCCSD
from qiskit_nature.second_q.mappers import JordanWignerMapper
from qiskit_nature.second_q.operators import FermionicOp
from qiskit_nature.second_q.circuit.library import UCCSD, HartreeFock
from qiskit_algorithms import EigensolverResult

# Your previously defined Hamiltonian as FermionicOp
#hamiltonian_fermionic_op = FermionicOp({...})  # Replace with your actual Hamiltonian terms

# Create a SecondQuantizedOp
#second_quantized_hamiltonian = SecondQuantizedOp(hamiltonian_fermionic_op)

spsa_optimizer = SPSA(maxiter=500)

noiseless_estimator = AerEstimator(
    run_options={"shots": 10000}
)

mapper = JordanWignerMapper()

num_spin_orbitals=3
num_particles=[2,2]

ansatz = UCCSD(
    num_spin_orbitals,
    num_particles,
    mapper,
    initial_state=HartreeFock(
        num_spin_orbitals,
        num_particles,
        mapper,
    ),
)

callback_dict = {
        "eval_count": 0,
        "params": None,
        "meta": {},
        "value": 0,
    }

vqe_solver = VQE(estimator=noiseless_estimator, ansatz=ansatz, optimizer=spsa_optimizer, callback=optimization_callback)

# Create a mapping from FermionicOp to qubits
mapper = JordanWignerMapper()

# Setup the GroundStateEigensolver
calc = GroundStateEigensolver(mapper, vqe_solver)

# Solve the problem using the SecondQuantizedOp
result = calc.solve(problem)

print(result)
# Out:
# Evaluation Count: 1
# Parameters: [-2.1268562430281603, -2.0193781522365297, -1.677995447803837, 5.412663269131554, -5.347425400383837, 0.6671853401830774, -1.0176533361671558, -0.1583628058977123]
# Estimated Value: -0.6016609600234929
# Metadata: {'shots': 10000, 'variance': 0.02469872402513302, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001697042, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010615667, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 2
# Parameters: [-2.5268562430281607, -1.6193781522365296, -2.077995447803837, 5.012663269131553, -5.747425400383837, 1.0671853401830773, -1.4176533361671557, 0.24163719410228773]
# Estimated Value: -0.6187041320426361
# Metadata: {'shots': 10000, 'variance': 0.022993625092234973, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001676167, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010270083, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 3
# Parameters: [-2.5268562430281607, -2.0193781522365297, -1.677995447803837, 5.412663269131554, -5.747425400383837, 1.0671853401830773, -1.4176533361671557, -0.1583628058977123]
# Estimated Value: -0.5963578349116339
# Metadata: {'shots': 10000, 'variance': 0.021850313190833248, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.00153675, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010663666, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 4
# Parameters: [-2.1268562430281603, -1.6193781522365296, -2.077995447803837, 5.012663269131553, -5.347425400383837, 0.6671853401830774, -1.0176533361671558, 0.24163719410228773]
# Estimated Value: -0.5876135157672026
# Metadata: {'shots': 10000, 'variance': 0.022207873165442656, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001687209, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.01029175, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 5
# Parameters: [-2.1268562430281603, -2.0193781522365297, -2.077995447803837, 5.412663269131554, -5.347425400383837, 0.6671853401830774, -1.0176533361671558, -0.1583628058977123]
# Estimated Value: -0.5781477414660207
# Metadata: {'shots': 10000, 'variance': 0.023722112257758297, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001673875, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010891209, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 6
# Parameters: [-2.5268562430281607, -1.6193781522365296, -1.677995447803837, 5.012663269131553, -5.747425400383837, 1.0671853401830773, -1.4176533361671557, 0.24163719410228773]
# Estimated Value: -0.6244394437095486
# Metadata: {'shots': 10000, 'variance': 0.018763422759825576, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001613083, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010407875, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 7
# Parameters: [-2.5268562430281607, -1.6193781522365296, -2.077995447803837, 5.412663269131554, -5.347425400383837, 0.6671853401830774, -1.0176533361671558, -0.1583628058977123]
# Estimated Value: -0.5999186282402197
# Metadata: {'shots': 10000, 'variance': 0.027704566829468147, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001476042, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010442, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 8
# Parameters: [-2.1268562430281603, -2.0193781522365297, -1.677995447803837, 5.012663269131553, -5.747425400383837, 1.0671853401830773, -1.4176533361671557, 0.24163719410228773]
# Estimated Value: -0.6214465502313576
# Metadata: {'shots': 10000, 'variance': 0.020071266166499194, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.00181325, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010158375, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 9
# Parameters: [-2.1268562430281603, -1.6193781522365296, -2.077995447803837, 5.412663269131554, -5.347425400383837, 1.0671853401830773, -1.0176533361671558, -0.1583628058977123]
# Estimated Value: -0.5860565764560424
# Metadata: {'shots': 10000, 'variance': 0.021184865810948424, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001790083, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.01011975, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 10
# Parameters: [-2.5268562430281607, -2.0193781522365297, -1.677995447803837, 5.012663269131553, -5.747425400383837, 0.6671853401830774, -1.4176533361671557, 0.24163719410228773]
# Estimated Value: -0.599363367545982
# Metadata: {'shots': 10000, 'variance': 0.019917611892719803, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.002352583, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010068208, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 11
# Parameters: [-2.1268562430281603, -1.6193781522365296, -2.077995447803837, 5.412663269131554, -5.747425400383837, 1.0671853401830773, -1.0176533361671558, 0.24163719410228773]
# Estimated Value: -0.6206983193800077
# Metadata: {'shots': 10000, 'variance': 0.02210126636857502, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.002760916, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.0104105, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 12
# Parameters: [-2.5268562430281607, -2.0193781522365297, -1.677995447803837, 5.012663269131553, -5.347425400383837, 0.6671853401830774, -1.4176533361671557, -0.1583628058977123]
# Estimated Value: -0.5902584798518473
# Metadata: {'shots': 10000, 'variance': 0.02138238249180928, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001699708, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.009586333, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 13
# Parameters: [-2.1268562430281603, -2.0193781522365297, -1.677995447803837, 5.412663269131554, -5.347425400383837, 0.6671853401830774, -1.4176533361671557, -0.1583628058977123]
# Estimated Value: -0.6093517774207549
# Metadata: {'shots': 10000, 'variance': 0.027161692927719683, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001676042, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.009380584, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 14
# Parameters: [-2.5268562430281607, -1.6193781522365296, -2.077995447803837, 5.012663269131553, -5.747425400383837, 1.0671853401830773, -1.0176533361671558, 0.24163719410228773]
# Estimated Value: -0.6275117673783748
# Metadata: {'shots': 10000, 'variance': 0.026941180937447868, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.002318917, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.009201375, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 15
# Parameters: [-2.1268562430281603, -1.6193781522365296, -2.077995447803837, 5.412663269131554, -5.747425400383837, 1.0671853401830773, -1.0176533361671558, -0.1583628058977123]
# Estimated Value: -0.6207584207944159
# Metadata: {'shots': 10000, 'variance': 0.022302369679026796, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001868791, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010101875, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 16
# Parameters: [-2.5268562430281607, -2.0193781522365297, -1.677995447803837, 5.012663269131553, -5.347425400383837, 0.6671853401830774, -1.4176533361671557, 0.24163719410228773]
# Estimated Value: -0.5900455924210645
# Metadata: {'shots': 10000, 'variance': 0.01992656911219498, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.003060334, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.009982583, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 17
# Parameters: [-2.1268562430281603, -2.0193781522365297, -2.077995447803837, 5.012663269131553, -5.747425400383837, 0.6671853401830774, -1.0176533361671558, -0.1583628058977123]
# Estimated Value: -0.6022971882117059
# Metadata: {'shots': 10000, 'variance': 0.022320923722367034, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001849916, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010457458, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 18
# Parameters: [-2.5268562430281607, -1.6193781522365296, -1.677995447803837, 5.412663269131554, -5.347425400383837, 1.0671853401830773, -1.4176533361671557, 0.24163719410228773]
# Estimated Value: -0.6072851893470631
# Metadata: {'shots': 10000, 'variance': 0.019873371171175935, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001693959, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010489583, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 19
# Parameters: [-2.1268562430281603, -1.6193781522365296, -1.677995447803837, 5.412663269131554, -5.347425400383837, 1.0671853401830773, -1.0176533361671558, 0.24163719410228773]
# Estimated Value: -0.5976693745654018
# Metadata: {'shots': 10000, 'variance': 0.022741888453785608, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.002370708, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010200959, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 20
# Parameters: [-2.5268562430281607, -2.0193781522365297, -2.077995447803837, 5.012663269131553, -5.747425400383837, 0.6671853401830774, -1.4176533361671557, -0.1583628058977123]
# Estimated Value: -0.5900652525226521
# Metadata: {'shots': 10000, 'variance': 0.027818683492508763, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001802375, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.009863959, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 21
# Parameters: [-2.1268562430281603, -2.0193781522365297, -2.077995447803837, 5.412663269131554, -5.347425400383837, 0.6671853401830774, -1.0176533361671558, -0.1583628058977123]
# Estimated Value: -0.5781477414660207
# Metadata: {'shots': 10000, 'variance': 0.023722112257758297, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001673875, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010891209, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 22
# Parameters: [-2.5268562430281607, -1.6193781522365296, -1.677995447803837, 5.012663269131553, -5.747425400383837, 1.0671853401830773, -1.4176533361671557, 0.24163719410228773]
# Estimated Value: -0.6244394437095486
# Metadata: {'shots': 10000, 'variance': 0.018763422759825576, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001613083, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010407875, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 23
# Parameters: [-2.5268562430281607, -2.0193781522365297, -1.677995447803837, 5.412663269131554, -5.747425400383837, 1.0671853401830773, -1.4176533361671557, -0.1583628058977123]
# Estimated Value: -0.5963578349116339
# Metadata: {'shots': 10000, 'variance': 0.021850313190833248, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.00153675, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010663666, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 24
# Parameters: [-2.1268562430281603, -1.6193781522365296, -2.077995447803837, 5.012663269131553, -5.347425400383837, 0.6671853401830774, -1.0176533361671558, 0.24163719410228773]
# Estimated Value: -0.5876135157672026
# Metadata: {'shots': 10000, 'variance': 0.022207873165442656, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001687209, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.01029175, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 25
# Parameters: [-2.1268562430281603, -2.0193781522365297, -1.677995447803837, 5.012663269131553, -5.347425400383837, 1.0671853401830773, -1.4176533361671557, 0.24163719410228773]
# Estimated Value: -0.5858567700798799
# Metadata: {'shots': 10000, 'variance': 0.023256217067627746, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.002559458, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.0097695, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 26
# Parameters: [-2.5268562430281607, -1.6193781522365296, -2.077995447803837, 5.412663269131554, -5.747425400383837, 0.6671853401830774, -1.0176533361671558, -0.1583628058977123]
# Estimated Value: -0.61396798765676
# Metadata: {'shots': 10000, 'variance': 0.02849348229309673, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.003367125, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.011619791, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 27
# Parameters: [-2.1268562430281603, -2.0193781522365297, -2.077995447803837, 5.412663269131554, -5.747425400383837, 1.0671853401830773, -1.4176533361671557, 0.24163719410228773]
# Estimated Value: -0.6022922779011363
# Metadata: {'shots': 10000, 'variance': 0.021563043553243205, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001900917, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.009767125, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 28
# Parameters: [-2.5268562430281607, -1.6193781522365296, -1.677995447803837, 5.012663269131553, -5.347425400383837, 0.6671853401830774, -1.0176533361671558, -0.1583628058977123]
# Estimated Value: -0.6153471583457912
# Metadata: {'shots': 10000, 'variance': 0.01876324957200859, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001607792, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.009733541, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 29
# Parameters: [-2.5268562430281607, -1.6193781522365296, -2.077995447803837, 5.412663269131554, -5.747425400383837, 1.0671853401830773, -1.4176533361671557, 0.24163719410228773]
# Estimated Value: -0.6138130750222757
# Metadata: {'shots': 10000, 'variance': 0.023432049480251946, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001428292, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010236125, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 30
# Parameters: [-2.1268562430281603, -2.0193781522365297, -1.677995447803837, 5.012663269131553, -5.347425400383837, 0.6671853401830774, -1.0176533361671558, -0.1583628058977123]
# Estimated Value: -0.6006591749199309
# Metadata: {'shots': 10000, 'variance': 0.02471929495911287, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001557, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.0108095, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 31
# Parameters: [-2.5268562430281607, -1.6193781522365296, -2.077995447803837, 5.012663269131553, -5.747425400383837, 1.0671853401830773, -1.4176533361671557, -0.1583628058977123]
# Estimated Value: -0.6142579300888094
# Metadata: {'shots': 10000, 'variance': 0.02830724407841982, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.002164666, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010441791, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 32
# Parameters: [-2.1268562430281603, -2.0193781522365297, -1.677995447803837, 5.412663269131554, -5.347425400383837, 0.6671853401830774, -1.0176533361671558, 0.24163719410228773]
# Estimated Value: -0.6012939538373858
# Metadata: {'shots': 10000, 'variance': 0.024360763530483633, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001625333, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010452291, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 33
# Parameters: [-2.5268562430281607, -2.0193781522365297, -2.077995447803837, 5.412663269131554, -5.747425400383837, 0.6671853401830774, -1.0176533361671558, -0.1583628058977123]
# Estimated Value: -0.5874745153744293
# Metadata: {'shots': 10000, 'variance': 0.028311376661308698, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001698083, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010817125, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 34
# Parameters: [-2.1268562430281603, -1.6193781522365296, -1.677995447803837, 5.012663269131553, -5.347425400383837, 1.0671853401830773, -1.4176533361671557, 0.24163719410228773]
# Estimated Value: -0.598085138240883
# Metadata: {'shots': 10000, 'variance': 0.022887047833090278, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001713166, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010369708, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 35
# Parameters: [-2.1268562430281603, -2.0193781522365297, -1.677995447803837, 5.012663269131553, -5.347425400383837, 0.6671853401830774, -1.4176533361671557, 0.24163719410228773]
# Estimated Value: -0.6100727850833499
# Metadata: {'shots': 10000, 'variance': 0.02674598052811883, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001796, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010047458, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 36
# Parameters: [-2.5268562430281607, -1.6193781522365296, -2.077995447803837, 5.412663269131554, -5.747425400383837, 1.0671853401830773, -1.0176533361671558, -0.1583628058977123]
# Estimated Value: -0.6189374693849494
# Metadata: {'shots': 10000, 'variance': 0.02839998230158515, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001628583, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.009893625, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 37
# Parameters: [-2.5268562430281607, -2.0193781522365297, -1.677995447803837, 5.412663269131554, -5.747425400383837, 0.6671853401830774, -1.4176533361671557, 0.24163719410228773]
# Estimated Value: -0.5994846313485354
# Metadata: {'shots': 10000, 'variance': 0.020071381584837955, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.002126292, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010434375, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 38
# Parameters: [-2.1268562430281603, -1.6193781522365296, -2.077995447803837, 5.012663269131553, -5.347425400383837, 1.0671853401830773, -1.0176533361671558, -0.1583628058977123]
# Estimated Value: -0.5859477438126901
# Metadata: {'shots': 10000, 'variance': 0.021390645453344112, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.002322667, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010575875, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 39
# Parameters: [-2.5268562430281607, -2.0193781522365297, -1.677995447803837, 5.012663269131553, -5.747425400383837, 1.0671853401830773, -1.0176533361671558, -0.1583628058977123]
# Estimated Value: -0.601959233891942
# Metadata: {'shots': 10000, 'variance': 0.024810124856762497, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001642125, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.009960834, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 40
# Parameters: [-2.1268562430281603, -1.6193781522365296, -2.077995447803837, 5.412663269131554, -5.347425400383837, 0.6671853401830774, -1.4176533361671557, 0.24163719410228773]
# Estimated Value: -0.5925433093396101
# Metadata: {'shots': 10000, 'variance': 0.023706334731445004, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.002355667, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.009879541, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 41
# Parameters: [-2.5268562430281607, -1.6193781522365296, -1.677995447803837, 5.012663269131553, -5.747425400383837, 0.6671853401830774, -1.0176533361671558, -0.1583628058977123]
# Estimated Value: -0.6302741017557878
# Metadata: {'shots': 10000, 'variance': 0.021387691654617465, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.002520292, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.009881375, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 42
# Parameters: [-2.1268562430281603, -2.0193781522365297, -2.077995447803837, 5.412663269131554, -5.347425400383837, 1.0671853401830773, -1.4176533361671557, 0.24163719410228773]
# Estimated Value: -0.5699686179963575
# Metadata: {'shots': 10000, 'variance': 0.020542442935582023, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001996292, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.009762041, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 43
# Parameters: [-2.5268562430281607, -2.0193781522365297, -1.677995447803837, 5.012663269131553, -5.347425400383837, 1.0671853401830773, -1.4176533361671557, 0.24163719410228773]
# Estimated Value: -0.5810458674525641
# Metadata: {'shots': 10000, 'variance': 0.02119213947923973, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001625291, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010048875, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 44
# Parameters: [-2.1268562430281603, -1.6193781522365296, -2.077995447803837, 5.412663269131554, -5.747425400383837, 0.6671853401830774, -1.0176533361671558, -0.1583628058977123]
# Estimated Value: -0.6167146506007521
# Metadata: {'shots': 10000, 'variance': 0.02231931937271904, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.00202875, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010652541, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 45
# Parameters: [-2.5268562430281607, -2.0193781522365297, -1.677995447803837, 5.412663269131554, -5.347425400383837, 1.0671853401830773, -1.0176533361671558, 0.24163719410228773]
# Estimated Value: -0.5837076654765242
# Metadata: {'shots': 10000, 'variance': 0.023138799023886752, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.002146666, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.0095815, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 46
# Parameters: [-2.1268562430281603, -1.6193781522365296, -2.077995447803837, 5.012663269131553, -5.747425400383837, 0.6671853401830774, -1.4176533361671557, -0.1583628058977123]
# Estimated Value: -0.6117193387770347
# Metadata: {'shots': 10000, 'variance': 0.02222168381532851, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.005565375, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.012130667, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 47
# Parameters: [-2.5268562430281607, -1.6193781522365296, -2.077995447803837, 5.412663269131554, -5.747425400383837, 1.0671853401830773, -1.0176533361671558, -0.1583628058977123]
# Estimated Value: -0.6189374693849494
# Metadata: {'shots': 10000, 'variance': 0.02839998230158515, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001628583, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.009893625, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 48
# Parameters: [-2.1268562430281603, -2.0193781522365297, -1.677995447803837, 5.012663269131553, -5.347425400383837, 0.6671853401830774, -1.4176533361671557, 0.24163719410228773]
# Estimated Value: -0.6100727850833499
# Metadata: {'shots': 10000, 'variance': 0.02674598052811883, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001796, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010047458, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 49
# Parameters: [-2.5268562430281607, -1.6193781522365296, -2.077995447803837, 5.412663269131554, -5.347425400383837, 1.0671853401830773, -1.0176533361671558, -0.1583628058977123]
# Estimated Value: -0.6027689928635491
# Metadata: {'shots': 10000, 'variance': 0.028574564969138558, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.002234292, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.009844083, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 50
# Parameters: [-2.1268562430281603, -2.0193781522365297, -1.677995447803837, 5.012663269131553, -5.747425400383837, 0.6671853401830774, -1.4176533361671557, 0.24163719410228773]
# Estimated Value: -0.6297535760399852
# Metadata: {'shots': 10000, 'variance': 0.020853518504349435, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.002960709, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010748542, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 51
# Parameters: [-2.1268562430281603, -1.6193781522365296, -2.077995447803837, 5.012663269131553, -5.747425400383837, 1.0671853401830773, -1.0176533361671558, 0.24163719410228773]
# Estimated Value: -0.6246503869449348
# Metadata: {'shots': 10000, 'variance': 0.022283636029061707, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001956708, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.011157709, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 52
# Parameters: [-2.5268562430281607, -2.0193781522365297, -1.677995447803837, 5.412663269131554, -5.347425400383837, 0.6671853401830774, -1.4176533361671557, -0.1583628058977123]
# Estimated Value: -0.5901801450666548
# Metadata: {'shots': 10000, 'variance': 0.021271276652807588, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001770375, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.009987833, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 53
# Parameters: [-1.47883752639634, -0.971359435604709, -3.0989687590103907, 3.9916899579250007, -6.76839871159039, 1.7152040568148978, 0.003319975039397738, 1.2626105053088412]
# ...
# Evaluation Count: 1036
# Parameters: [-1.6760827211063176, -2.880069148549338, -3.017771777361945, 4.826568012341606, -6.412211600607711, 1.4628938127164004, -1.6820575365569408, 0.9665148507810599]
# Estimated Value: -0.6702407616041222
# Metadata: {'shots': 10000, 'variance': 0.004725859400953454, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.005525917, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.013613834, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 1037
# Parameters: [-1.6750094283980186, -2.878995855841039, -3.0188450700702436, 4.825494719633307, -6.1973452645643405, 1.4639671054246994, -1.4671912005135708, 0.7516485147376899]
# Estimated Value: -0.6701374761029695
# Metadata: {'shots': 10000, 'variance': 0.004457622181049354, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001990709, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010450208, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 1038
# Parameters: [-1.4612163850629476, -2.6652028125059677, -3.232638113405315, 4.611701676298235, -6.411138307899412, 1.6777601487597704, -1.6809842438486418, 0.9654415580727609]
# Estimated Value: -0.6711511741277476
# Metadata: {'shots': 10000, 'variance': 0.003101043129291761, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.002363917, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010782375, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 1039
# Parameters: [-1.6736272936247587, -2.877613721067779, -3.0202272048435037, 4.824112584860047, -6.412476780590317, 1.6790986214506753, -1.6823227165395467, 0.9667800307636657]
# Estimated Value: -0.6706114795627934
# Metadata: {'shots': 10000, 'variance': 0.0042720054926724555, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.002064708, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.0103625, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 1040
# Parameters: [-1.4598779123720427, -2.6638643398150634, -3.2339765860962193, 4.6103632036073305, -6.1987273993376, 1.4653492401979593, -1.4685733352868307, 0.7530306495109497]
# Estimated Value: -0.6708825246196453
# Metadata: {'shots': 10000, 'variance': 0.003990628845912258, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001852792, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010584334, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 1041
# Parameters: [-1.459536341886934, -2.87722858550755, -3.2343181565813284, 4.610021633122222, -6.412091645030087, 1.4650076697128507, -1.468231764801722, 0.9663948952034362]
# Estimated Value: -0.6702932388548295
# Metadata: {'shots': 10000, 'variance': 0.004271665611254388, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001970917, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010446125, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 1042
# Parameters: [-1.6732421580645294, -2.6635227693299544, -3.0206123404037326, 4.823727449299818, -6.198385828852492, 1.678713485890446, -1.6819375809793173, 0.7526890790258409]
# Estimated Value: -0.671080089999119
# Metadata: {'shots': 10000, 'variance': 0.004078881614049643, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001728791, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010254875, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 1043
# Parameters: [-1.4606118338028782, -2.8761530935916055, -3.233242664665384, 4.824759472737418, -6.197353805414891, 1.6797455093280476, -1.4693072567176662, 0.7516570555882394]
# Estimated Value: -0.6702600872402897
# Metadata: {'shots': 10000, 'variance': 0.00434898607254624, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.002595917, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010323292, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 1044
# Parameters: [-1.674274181502131, -2.662490745892353, -3.019580316966131, 4.6110971250381665, -6.411016153114143, 1.4660831616287948, -1.682969604416919, 0.9653194032874919]
# Estimated Value: -0.6715542072636094
# Metadata: {'shots': 10000, 'variance': 0.003618842946849857, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.002360209, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.01094925, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 1045
# Parameters: [-1.6759838438647505, -2.8744000589395227, -3.231489630013301, 4.609387462675547, -6.199106840066974, 1.6779924746759645, -1.4710602913697493, 0.9670290656501117]
# Estimated Value: -0.6701625719559504
# Metadata: {'shots': 10000, 'variance': 0.004054837983479951, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.002432333, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010868833, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 1046
# Parameters: [-1.4623648684549613, -2.660781083529733, -3.0178706546035112, 4.8230064380853355, -6.412725815476763, 1.4643734992661752, -1.6846792667795385, 0.7534100902403222]
# Estimated Value: -0.6711637977053885
# Metadata: {'shots': 10000, 'variance': 0.0036651317310341137, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.002075958, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010433958, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 1047
# Parameters: [-1.461048357318604, -2.8730402712972203, -3.2301298423709985, 4.824322949221693, -6.200466627709276, 1.6766326870336625, -1.6859957779158958, 0.7520935791039649]
# Estimated Value: -0.6702337718209554
# Metadata: {'shots': 10000, 'variance': 0.0042194647754492335, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001938917, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010315916, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 1048
# Parameters: [-1.6746240562224486, -2.6594645723933756, -3.016554143467154, 4.610747250317849, -6.41404232661312, 1.4630569881298179, -1.4724200790120512, 0.9656692780078096]
# Estimated Value: -0.6715199022997587
# Metadata: {'shots': 10000, 'variance': 0.003274004637254954, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.0018635, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010356708, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 1049
# Parameters: [-1.6763196667189064, -2.6577689618969176, -3.014858532970696, 4.822584157599963, -6.202205419331006, 1.6748938954119332, -1.6842569862941665, 0.9673648885042674]
# Estimated Value: -0.6711767256848362
# Metadata: {'shots': 10000, 'variance': 0.00421874735997335, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.002028125, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010508292, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 1050
# Parameters: [-1.4627871489403332, -2.871301479675491, -3.2283910507492695, 4.6090516398213905, -6.415737937109578, 1.46136137763336, -1.4707244685155934, 0.7538323707256942]
# Estimated Value: -0.6704147800545363
# Metadata: {'shots': 10000, 'variance': 0.00409680272094628, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.00187425, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.010662416, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# Evaluation Count: 1051
# Parameters: [-1.5705697138571462, -2.763518914758678, -3.1206084858324563, 4.716834204738203, -6.307955372192766, 1.569143942550173, -1.5785070334324063, 0.861614935642507]
# Estimated Value: -0.6740358459549711
# Metadata: {'shots': 10000, 'variance': 3.9832134585579634e-05, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.001901, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1, 2, 3, 4, 5], 'device': 'CPU', 'time_taken': 0.01073125, 'measure_sampling': True, 'num_clbits': 6, 'max_memory_mb': 32768, 'input_qubit_map': [[5, 5], [4, 4], [3, 3], [2, 2], [1, 1], [0, 0]], 'num_qubits': 6, 'method': 'statevector', 'required_memory_mb': 1, 'fusion': {'enabled': True, 'threshold': 14, 'applied': False, 'max_fused_qubits': 5}}]}
# {   'aux_operators_evaluated': [   {   'spin_correlator': (-0.002725-0.0006249999999999997j)}],
#     'eigenstates': [   (   <qiskit_nature.second_q.circuit.library.ansatzes.uccsd.UCCSD object at 0x318623e30>,
#                            array([-1.57056971, -2.76351891, -3.12060849,  4.7168342 , -6.30795537,
#         1.56914394, -1.57850703,  0.86161494]))],
#     'eigenvalues': array([-0.67403585]),
#     'formatting_precision': 12,
#     'groundenergy': -0.6740358459549711,
#     'groundstate': (   <qiskit_nature.second_q.circuit.library.ansatzes.uccsd.UCCSD object at 0x318623e30>,
#                        array([-1.57056971, -2.76351891, -3.12060849,  4.7168342 , -6.30795537,
#         1.56914394, -1.57850703,  0.86161494])),
#     'raw_result': <qiskit_algorithms.minimum_eigensolvers.vqe.VQEResult object at 0x1573cc230>}

# %%
import pandas as pd
import os

# After optimization, you can convert lists to numpy arrays if needed:
evaluation_counts_array = np.array(evaluation_counts)
params_array = np.array(params_list)  # Note: This will be a 2D array if params have different lengths
estimated_values_array = np.array(estimated_values)
metadata_array = np.array(metadata_list)  # This will also be a 2D array or object array

# Save the data to CSV files
pd.DataFrame(evaluation_counts_array, columns=['Evaluation Count']).to_csv('results/evaluation_counts.csv', index=False)
pd.DataFrame(params_array).to_csv('results/parameters.csv', index=False)
pd.DataFrame(estimated_values_array, columns=['Estimated Value']).to_csv('results/estimated_values.csv', index=False)
pd.DataFrame(metadata_array).to_csv('results/metadata.csv', index=False)

# %%
print("Local AER simulator result:\n")
print(result.groundenergy)
# Out:
# Local AER simulator result:
#
# -0.6740358459549711
